# %% [markdown]
# # **_My First Notebook Usecase Work_**
# ## **_To display our WD36 batch group photo_**
# <span style="color:red">Name: Parthasarathi M</span>
#
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql

CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics

# %%
# %run
"/Workspace/Users/ampsarathi283@gmail.com/databricks-code-repo/databricks_workouts_2025/databricks_notebook_fundamentals/4_child_nb_dataload"

# %%
# %fs
head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
# %py
df1 = spark.read.option("header", True).csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df1)

# %%
# %py
df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %%
# %sql
select * from mobile_os_usage

# %%
# %py

def upper_case(name):
    return name.upper()

name = upper_case('hello how are you')
print(name)

# %%
# %pip install pandas

# %%
import pandas as pd

df_pd = pd.read_csv('/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv')
display(df_pd)

# %%
# %sh
echo "Magic commands tasks completed"
